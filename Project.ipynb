# %% [markdown]
# # Predicting the fare amount charges of NYC yellow taxi

# %% [markdown]
# ## Executive summary
# ### By Divinefavour Osasenaga Odion

# %% [markdown]
# ## Introduction and Background  of the Study
#
# The Newyork City (NYC) yellow taxi is a organization owning several thousands of taxi cabs in Newyork city USA. These taxis are the only vehicles authorized to pick up and transport street-hailing and prearranged passengers anywhere in the city (see https://www.nyc.gov/site/tlc/businesses/yellow-cab.page). The dataset presented in the analysis and modelling carried out in the Report below is one consisting of features that capture information about single taxi trips in Newyork city.The fare amount and other features were provided to the NYC Taxi and Limousine Commission (TLC) by technology providers authorized under the Taxicab & Livery Passenger Enhancement Programs (TPEP/LPEP).

# %% [markdown]
# ## Tasks/Goals
#
# The aim of this study is to analyse the historical data contained in the New york yellow taxi dataset provided. This analysis effort seeks to find/uncover relationships between the variables contained in the data to ascertain if it is possible to train a predictive model to predict the fare amount charge (target variable) of trips. One real-world application of the results would be to offer actionable insights to everyday users of the yellow taxi service to aid their decision-making.
# A second angle to view the upside of results of such analysis is the possible benefits that it offers to the the yellow taxi company. The ability to predict trip charges before-hand given certain factors opens up a new Revenue model that the taxi company could exploit. For example, by offering/upselling this as an extra service in a mobile application

# %% [markdown]
# ## Approach/Method
# The methods used to achieve the objectives listed in the section above are grouped into 3 sequential parts which are;
# 1. Data Pipeline and Cleaning
# 2. Exploratory Data Analysis and Transformation
# 3. Machine learning modelling
#
#
#
#
# Data Pipeline and Cleaning: In this phase the data is extracted from the csv files into dataframes for computing on. Rows containing missing values and redundant features will be removed, the data types of the variable columns will be determined and the necessary preliminary transformations will be carried out on the data to prepare for analysis.
#
#
#
# Exploratory data Analysis: In this phase the dependent variables will be explored to determine relationships in order to generate the best features for predicting the target variable fare amount. The variables/featur in the dataset are listed and described as follows;
#
#
# - VendorID:	A code indicating the TPEP provider that provided the record.
#     - Creative Mobile Technologies
#     - VeriFone Inc.
# - tpep_pickup_datetime:	The date and time when the meter was engaged.
# - tpep_dropoff_datetime:	The date and time when the meter was disengaged.
# - Passenger_count:	The number of passengers in the vehicle. This is a driver-entered value.
# - Trip_distance:	The elapsed trip distance in miles reported by the taximeter.
# - Pickup_longitude:	Longitude where the meter was engaged.
# - Pickup_latitude:	Latitude where the meter was engaged.
# - RateCodeID:	The final rate code in effect at the end of the trip.
#     - Standard rate
#     - JFK
#     - Newark
#     - Nassau or Westchester
#     - Negotiated fare
#     - Group ride
# - Store_and_fwd_flag:	This flag indicates whether the trip record was held in vehicle memory before sending to the vendor,                          aka “store and forward,” because the vehicle did not have a connection to the server.
#     - Y= store and forward trip
#     - N= not a store and forward trip
# - Dropoff_longitude:	Longitude where the meter was disengaged.
# - Dropoff_ latitude:	Latitude where the meter was disengaged.
# - Payment_type:	A numeric code signifying how the passenger paid for the trip.
#     - Credit card
#     - Cash
#     - No charge
#     - Dispute
#     - Unknown
#     - Voided trip
# - Fare_amount:	The time-and-distance fare calculated by the meter.
# - Extra:	Miscellaneous extras and surcharges. Currently, this only includes. the $0.50 and $1 rush hour and overnight                  charges.
# - MTA_tax:	0.50 MTA tax that is automatically triggered based on the metered rate in use.
# - Improvement_surcharge:	0.30 improvement surcharge assessed trips at the flag drop. the improvement surcharge began being                             levied in 2015.
# - Tip amount: This field is automatically populated for credit card tips.Cash tips are not included.
# - Tolls_amount:	Total amount of all tolls paid in trip.
# - Total_amount:	The total amount charged to passengers. Does not include cash tips.
# - GoodTip:	Categorical variable indicating an above average tip
# - Extra:	An indicator for additional charges included.
# - Cash:	An indicator whether payment was made by cash or not
#
# Souces:
# - [Download dataset here](https://github.com/divineod/Data_Analaytics_Project.)
#
#
# Machine Learning modelling: After performing EDA on the dataset and determining the best predictors of the fare amount the data will be split randomly into training and test sets. A baseline linear regression model will then be trained and evaluated on the test set using key error metrics including the Root mean sqaure (rmse) error and Mean Absolute percentage error (MAPE). Building upon the baseline, more complex machine learning algorithms will be trained and cross validated on the data and then evaluated on the test set to determine the best model. Finally, the selected model will be fine-tuned with the aim of increasing the prediction accuracy.

# %% [markdown]
# ## Results
#
# 1. A trip within New york city should most times cost below 20 USD.
# 2. There are fixed price trips at around 50 - 60 dollar range that suggest a standard price for trips to the airport.
# 3. Majority of the taxi trips within New york are short distance and fall below 4 miles.
# 4. From the dataset average cost per mile of a trip about  4.33 USD -  6 USD.
# 5. There exists a somewhat direct linear relationship between the trip distance and the fare amount. An increase in the trip distance translates to an increase in the fare amount and vice versa.
# 6. The peak (busiest) hours of the day, where the fare amount charges are also the highest are between 12:00 pm to 1:00 pm.
# 7. There exist extra charges that affect the total amount charged on the trip that usually start incurring during the peak hours (around 12:00pm to 1:00pm) and continues through the late hours (up till around 23:00pm).
# 8. While the direction of the trip has an influence on the fare amount charged, it's effect are not as significant as the trip distance.
# 9. There are three airports in Newyork city and trips to/from these locations are usually at a fixed price.
# 10. The most important predictor of the fare amount charges is the trip distance feature.
# 11. The number of passengers in a trip has no effect on the fare amount charged at the end of the trip.
# 12. To predict the fare amount of a single taxi trip in Newyork with reasonable accuracy it is sufficient to know the point-to-point distance, the time of the day and the Rate code applied for the trip.

# %% [markdown]
# ## Recommendations based on results
# 1. The number of persons in a taxi during a trip does not have an effect on the fare price charged at the end of the trip, so it might be insightful for people to travel in groups when possible to save money.
# 2. It is cheaper to travel during the earlier hours of the day (5am - 12pm) than later due to extra charges incurred at rush-hour periods.

# %% [markdown]
# ## Install Analysis and modelling Libraries

# %% [raw]
# pip install numpy

# %%
pip install pandas==1.3.5
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install squarify
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install statsmodels
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install featurewiz --ignore-installed --no-deps
# Out:
# ...
#   Using cached featurewiz-0.2.3-py3-none-any.whl (111 kB)
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lazytransform
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install catboost
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/divinefavourodion/Documents/Data_Analytics_Project/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                  Version
# ------------------------ -----------
# anyio                    3.6.2
# appnope                  0.1.3
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asttokens                2.2.1
# attrs                    22.1.0
# backcall                 0.2.0
# beautifulsoup4           4.11.1
# bleach                   5.0.1
# catboost                 1.1.1
# category-encoders        2.4.0
# cffi                     1.15.1
# click                    8.1.3
# cloudpickle              2.2.0
# cmake                    3.25.0
# contourpy                1.0.6
# cycler                   0.11.0
# dask                     2022.12.0
# debugpy                  1.6.4
# decorator                5.1.1
# defusedxml               0.7.1
# entrypoints              0.4
# executing                1.2.0
# fastjsonschema           2.16.2
# featurewiz               0.2.3
# fonttools                4.38.0
# ...

# %% [markdown]
# # Introduction (Data Processing Pipeline)
#
# The objective of this analysis is to create a highly accurate model for predicting the fare amount charges on taxi trips within Newyork city (NYC). We have been provided a dataset containing 22 features and several thousand observations. First, we will be applying state-of-the-art data cleaning and transformation techniques to prepare the dataset for analysis and modeling. In the second stage we will explore the features in the dataset to understand the relationships between the target variable and other independent variables. Finally, after EDA we will train various models to compare and select a best performer using key error metrics (RMSE and MAPE). The selected model will be fine-tuned to improve its prediction accuracy and stored for further analysis purposes.

# %%
# Import all libraries used in Analysis
import numpy as np # linear algebra
import pandas as pd
import matplotlib.pyplot as plt #visualization
from matplotlib import ticker
import seaborn as sns
import math
import datetime as dt
import squarify
import warnings
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV, GridSearchCV, RepeatedKFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, explained_variance_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import uniform as sp_randFloat
from scipy.stats import randint as sp_randInt
from catboost import CatBoostRegressor
import pickle
warnings.simplefilter(action="ignore", category=FutureWarning)
# %matplotlib inline

# %%
# Read the Data and check the structure

taxi_df = pd.read_csv(r'/Users/divinefavourodion/Documents/Data_Analytics_Project/exam_data.csv')
taxi_df.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           1         2  2016-02-07 16:20:16   2016-02-07 16:25:24
# 1           2         2  2016-02-07 16:20:29   2016-02-07 16:33:41
# 2           3         1  2016-02-19 20:54:40   2016-02-19 21:02:02
# 3           4         1  2016-02-19 20:55:23   2016-02-19 21:05:03
# 4           5         2  2016-02-19 20:56:06   2016-02-19 21:01:03
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           1.04        -73.956322        40.781319
# 1                1           2.78        -73.987045        40.720921
# 2                1           2.40        -73.975731        40.758167
# 3                2           1.90        -73.961922        40.779140
# 4                5           0.47        -74.002571        40.739639
#
#    RatecodeID store_and_fwd_flag  ...  fare_amount  extra  mta_tax  \
# 0           1                  N  ...          6.0    0.0      0.5
# ...

# %%
# Drop any unnecessary columns in the dataframe

taxi_df = taxi_df.iloc[:, 1:]
taxi_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-02-07 16:20:16   2016-02-07 16:25:24                1
# 1         2  2016-02-07 16:20:29   2016-02-07 16:33:41                1
# 2         1  2016-02-19 20:54:40   2016-02-19 21:02:02                1
# 3         1  2016-02-19 20:55:23   2016-02-19 21:05:03                2
# 4         2  2016-02-19 20:56:06   2016-02-19 21:01:03                5
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.04        -73.956322        40.781319           1
# 1           2.78        -73.987045        40.720921           1
# 2           2.40        -73.975731        40.758167           1
# 3           1.90        -73.961922        40.779140           1
# 4           0.47        -74.002571        40.739639           1
#
#   store_and_fwd_flag  dropoff_longitude  ...  fare_amount  extra  mta_tax  \
# ...

# %% [markdown]
# We have 22 feature columns in total

# %%
# Check the data types corresponding to each column

taxi_df.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# pickup_longitude         float64
# pickup_latitude          float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# GoodTip                     bool
# Extra                       bool
# Cash                        bool
# dtype: object

# %% [markdown]
# The dataset consists of 16 numerical feature columns, two datetime object feature columns, and 3 boolean feature columns.
#
# In the dataset we have 8 categorical features and 14 continous variables

# %%
# Check for missing values in the dataset

print(taxi_df.isnull().sum())
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RatecodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# GoodTip                  0
# Extra                    0
# Cash                     0
# dtype: int64

# %% [markdown]
# ALl the columns are populated with no missing values therefore we can proceed with analysis

# %%
# Summary statistics of the dataset

taxi_df.describe()
# Out:
#            VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  28454.000000     28454.000000   28454.000000      28454.000000
# mean       1.529873         1.644444       2.858948        -72.874465
# std        0.499116         1.298786       3.495591          8.952359
# min        1.000000         0.000000       0.000000        -74.181519
# 25%        1.000000         1.000000       1.000000        -73.991653
# 50%        2.000000         1.000000       1.660000        -73.981583
# 75%        2.000000         2.000000       3.050000        -73.966949
# max        2.000000         6.000000      39.620000          0.000000
#
#        pickup_latitude    RatecodeID  dropoff_longitude  dropoff_latitude  \
# count     28454.000000  28454.000000       28454.000000      28454.000000
# mean         40.145532      1.042033         -72.905041         40.163241
# std           4.931766      0.864237           8.826272          4.862442
# ...

# %% [markdown]
# In the dataset we have a total of 28,454 rows with no missing values
# The target/dependent variable fare_amount has a standard deviation of 12.372738 from the average fare amount
# The mean value of 1.64 implies that we have an average of approximately 2 people on every ride.

# %% [markdown]
# To proceed with analysis we should drop all rows with negative values for the fare_amount as they do not mean anything and will not offer any insights to our predictive models

# %%
# Drop all rows with negative values for the fare charge, total amount and tip amount
predicate = (taxi_df.fare_amount<0) | (taxi_df.total_amount<0) | (taxi_df.tip_amount<0)
taxi_df.loc[~predicate ]
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2016-02-07 16:20:16   2016-02-07 16:25:24                1
# 1             2  2016-02-07 16:20:29   2016-02-07 16:33:41                1
# 2             1  2016-02-19 20:54:40   2016-02-19 21:02:02                1
# 3             1  2016-02-19 20:55:23   2016-02-19 21:05:03                2
# 4             2  2016-02-19 20:56:06   2016-02-19 21:01:03                5
# ...         ...                  ...                   ...              ...
# 28449         2  2016-02-28 23:48:22   2016-02-28 23:48:27                1
# 28450         2  2016-02-28 23:48:32   2016-02-29 00:10:57                1
# 28451         2  2016-02-28 23:50:25   2016-02-29 00:05:30                1
# 28452         2  2016-02-28 23:55:24   2016-02-29 00:02:03                2
# 28453         2  2016-02-29 00:01:48   2016-02-29 00:04:20                1
#
# ...

# %%
# Convert the columns containing date and time data to datetime objects to aid analysis across the time dimension
buffer_1 = []
buffer_2 = []

for i in range(len(taxi_df['tpep_pickup_datetime'])):
    buffer_1.append(pd.to_datetime(taxi_df['tpep_pickup_datetime'].iloc[i]))
    buffer_2.append(pd.to_datetime(taxi_df['tpep_dropoff_datetime'].iloc[i]))

taxi_df['tpep_pickup_datetime'] = buffer_1
taxi_df['tpep_dropoff_datetime'] = buffer_2

# %%
# Seperate the datetime components to smaller units including day, month, and time
taxi_df['tpep_pickup_datetime'] = pd.to_datetime(taxi_df['tpep_pickup_datetime'])
taxi_df['tpep_dropoff_datetime']= pd.to_datetime(taxi_df['tpep_dropoff_datetime'])


taxi_df['pickup_time'] = pd.DatetimeIndex(taxi_df['tpep_pickup_datetime']).time
taxi_df['pickup_day'] = pd.DatetimeIndex(taxi_df['tpep_pickup_datetime']).day
taxi_df['pickup_month'] = pd.DatetimeIndex(taxi_df['tpep_pickup_datetime']).month
taxi_df['pickup_year'] = pd.DatetimeIndex(taxi_df['tpep_pickup_datetime']).year
taxi_df['dropoff_time'] = pd.DatetimeIndex(taxi_df['tpep_dropoff_datetime']).time
taxi_df['dropoff_day'] = pd.DatetimeIndex(taxi_df['tpep_dropoff_datetime']).day
taxi_df['dropoff_month'] = pd.DatetimeIndex(taxi_df['tpep_dropoff_datetime']).month
taxi_df['dropoff_year'] = pd.DatetimeIndex(taxi_df['tpep_dropoff_datetime']).year

taxi_df['weekday'] = taxi_df.tpep_pickup_datetime.apply(lambda t: t.weekday())
taxi_df['pickup_hour'] = taxi_df.tpep_pickup_datetime.apply(lambda t: t.hour)
taxi_df['dropoff_hour'] = taxi_df.tpep_dropoff_datetime.apply(lambda t: t.hour)

taxi_df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2016-02-07 16:20:16   2016-02-07 16:25:24                1
# 1             2  2016-02-07 16:20:29   2016-02-07 16:33:41                1
# 2             1  2016-02-19 20:54:40   2016-02-19 21:02:02                1
# 3             1  2016-02-19 20:55:23   2016-02-19 21:05:03                2
# 4             2  2016-02-19 20:56:06   2016-02-19 21:01:03                5
# ...         ...                  ...                   ...              ...
# 28449         2  2016-02-28 23:48:22   2016-02-28 23:48:27                1
# 28450         2  2016-02-28 23:48:32   2016-02-29 00:10:57                1
# 28451         2  2016-02-28 23:50:25   2016-02-29 00:05:30                1
# 28452         2  2016-02-28 23:55:24   2016-02-29 00:02:03                2
# 28453         2  2016-02-29 00:01:48   2016-02-29 00:04:20                1
#
# ...

# %%
## Plot the distribution of the variables in the Dataset

# Get non-categorical column names
num_var =taxi_df.select_dtypes(include=['int64', 'float']).columns.tolist()
number_of_columns = 25
number_of_rows = int(len(num_var)-1 / number_of_columns)


plt.figure(figsize=(number_of_columns, number_of_rows))
for i in range(0, len(num_var)):
    plt.subplot(7, 4, i+1)
    sns.histplot(taxi_df[num_var[i]], kde=True, stat="density" )
    #plt.tight_layout()

# %% [markdown]
# The plots above show the distribution of the variables in the dataset. For variable specific analysis we can see that;
# 1. There exist two Vendor IDs that correspond to the TPEP provider of the data. The distribution plots show that more of the data samples were provided by the second vendor VeriFoneInc.
# 2. Majority (over 50%) of the taxi trips recorded in the data had a single passenger.
# 3. The trip distance variable is skewed to the right indicating more of shorter trips (<5km) populating this dataset.
# 4. Payment by card (1) is the popular choice in New york city which also suggests that majority of the trips are prebooked.
#     (See [here](https://www.investopedia.com/articles/personal-finance/021015/uber-versus-yellow-cabs-new-york-city.asp#:~:text=NYC%20cab%20drivers,through%20the%20app.)).
# 5. The fare amount (target) variable is skewed to the right with a slight peak around the 50 USD range that connotes fixed price trips perhaps to/fro the airports.
# 6. The total amount charges at the end of a trip are also skewed to the right with smaller peaks existing between the 50 USD - 100 USD range to further confirm the suspicions about the fixed price trips.
# 7. The data provided for this analysis was captured within the period of late 2015 to early  2016.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Visualize target/dependent fare_amount variable via  histogram
taxi_df.fare_amount.hist(bins=70, figsize=(20,7))
plt.xlabel('fare $USD')
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
plt.title('Histogram showing the fare distribution');

# %% [markdown]
# From the histogram above we can infer that:
# 1. Majority of the taxi trips within NYC charge less the 20 USD
# 2. There is a peak around the price 50 USD which indicates standard/fixed fare tags (e.g trip to/fro airport)

# %%
# Next let's visualize the distance of every trip to see what information we get

taxi_df.trip_distance.hist(bins=70, figsize=(20,7))
plt.xlabel('trip distance in miles')
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(2))
plt.title('Histogram showing the trip distance distribution');

# %% [markdown]
# The histogram shows that majority of the trips in NYC are shorter ones below 4 miles with some outlier trip distances above the 12 mile range.

# %%
# Let's take a look at the passenger count column
taxi_df.groupby('passenger_count')['trip_distance', 'fare_amount'].mean()
# Out:
#                  trip_distance  fare_amount
# passenger_count
# 0                     0.000000    17.160000
# 1                     2.811750    12.239883
# 2                     3.053880    12.983909
# 3                     2.935771    12.803853
# 4                     3.024829    12.927565
# 5                     2.851268    12.049349
# 6                     2.875380    12.296257

# %% [markdown]
# A passenger_count of zero coupled with an average trip distance of 0 is strange and might indicate some administrative errors (e.g zero distance trips being recorded). A calculation of the price per mile might be insightful

# %%
print("Average $USD/Mile : {:0.2f}".format(taxi_df.fare_amount.sum()/taxi_df.trip_distance.sum()))
# Out:
# Average $USD/Mile : 4.33

# %% [markdown]
# The average cost of a trip per mile is $4.33 (Note: from the raw uncleaned data captured)

# %% [markdown]
# For the Next step we would like to visualize the relationship between the distance traveled in a trip and the fare amount charged at the end of the trip. Our intuition is that these two variables would likely have the most significant correlation to aid in our modeling experiment.

# %%
# scatter plot distance - fare
fig, ax = plt.subplots(1, 2, figsize=(16,6))
ax[0].scatter(taxi_df.trip_distance, taxi_df.fare_amount, alpha=0.2)
ax[0].grid(True)
ax[0].set_xlabel('distance in miles')
ax[0].set_ylabel('fare $USD')
ax[0].set_title('All data')


# zoom in on part of data
idx = (taxi_df.trip_distance < 15) & (taxi_df.fare_amount < 100)
ax[1].scatter(taxi_df[idx].trip_distance, taxi_df[idx].fare_amount, alpha=0.2)
ax[1].grid(True)
ax[1].set_xlabel('distance in miles')
ax[1].set_ylabel('fare $USD')
ax[1].set_title('Zoom in on distance < 15 mile, fare < $100');

# %% [markdown]
# 1. The scatter plot clearly shows a trend in the fares (i.e an increase in the distance corresponds to an increase in the price). This also indicates that the 'trip_distance' will probably be a good predictor of the fares during modelling.
# 2. There seems to be a straight line of fares around 50 USD price. This further certifies our claim that there exists a fixed-price trip despite the distance (e.g to and fro the airport).
# 3. There are a few observations of long distance trips with low fare amount charges. These may be discounted trips or promotions.
# 3. In the data there are trips of zero distance (miles) but non-zero fares. This could indicate trips from and to the same location which will be difficult to model. So a step in the right direction would be to eliminate such trips from the dataframe before modelling.
# 4. Overall there exists a linear relationship between the fare charge and distance of trips with a average rate of approximately  20 USD/4 m = 5 $ / m.

# %% [markdown]
# Next, we will remove the zero distance trips in the dataset to improve the accuracy of the results of our Analysis.

# %%
# Check the number of entries with zero-mile distance covered in the trip
idx = (taxi_df.trip_distance == 0)
len(taxi_df.trip_distance[idx])
# Out:
# 154

# %% [markdown]
# There are 154 instances with zero distance covered during the trip. These instances will be filtered from the datset

# %%
# remove datapoints with distance <0.05 miles
idx = (taxi_df.trip_distance >= 0.05)
print('Old size: %d' % len(taxi_df))
taxi_df = taxi_df[idx]
print('New size: %d' % len(taxi_df))
# Out:
# Old size: 28454
# New size: 28275

# %% [markdown]
# Adding the fare/mile feature column to the dataset (for Analysis)

# %%
# Add a feature columns with the fare charge per mile
taxi_df['fare_per_mile'] = taxi_df.fare_amount / taxi_df.trip_distance
taxi_df.fare_per_mile.describe()
# Out:
# count    28275.000000
# mean         5.942368
# std          7.600751
# min        -61.904762
# 25%          4.219577
# 50%          5.349794
# 75%          6.785714
# max        866.666667
# Name: fare_per_mile, dtype: float64

# %% [markdown]
# The average fair per mile is 5.942368 after removing the zero-distance trips which makes sense because it corresponds with our estimates from the earlier plot of trip distance against fare amount. A quick google search further establishes this finding;
# Information gotten from [here](https://www.nyc.gov/site/tlc/passengers/taxi-fare.page#:~:text=%242.50%20initial%20charge.,when%20the%20vehicle%20is%20stopped.) shows how the standard metered fare is calculated;
#
# - There is a 2.50 USD initial (base) charge.
# - An extra 50 cents per 1/5 mile when traveling above 12mph or per 60 seconds in slow traffic or when the vehicle is stopped.
# - An extra 50 cents MTA State Surcharge for all trips that end in New York City or Nassau, Suffolk, Westchester, Rockland, Dutchess, Orange or Putnam Counties.
# - Plus 30 cents Improvement Surcharge.
# - Additional 50 cents overnight surcharge 8pm to 6am.
# - Plus 1.00 USD rush hour surcharge from 4pm to 8pm on weekdays, excluding holidays.
# - Plus New York State Congestion Surcharge of 2.50 USD (Yellow Taxi) or 2.75 USD (Green Taxi and FHV) or 75 cents (any shared ride) for all trips that begin, end or pass through Manhattan south of 96th Street.
# - Finally, tips and any tolls.
#
# We cannot determine the speed of a moving vehicle in this analysis but taking the assumptions from the information provided above we have a total of 2.5 USD for a trip of 1 mile.
# Excluding the extra charges and taxes (because the add up to the total amount which is not the target variable for this experiment) we have a fare amount of approximately 2.50 USD (initial charge) + 2.50 USD = 5.0 USD for a trip of 1km.
#
# Also, the max fair per mile seems too high to make sense therefore warranting some extra analysis
#
#
#
# Note: An important note to keep in mind is that distance in this analysis is point-to-point distance meanwhile, in reality the distance is measured by road and is usually larger.

# %% [markdown]
# In this next step, we aim to zoom in on trips below 3 mile traveling distance and visualize the fair amount to futher understand this relationship

# %%
# Plot the fair charges vs the trip_distance
idx = (taxi_df.trip_distance < 3) & (taxi_df.fare_amount < 100)
plt.scatter(taxi_df[idx].trip_distance, taxi_df[idx].fare_per_mile)
plt.xlabel('Distance in miles')
plt.ylabel('fare charge')

# theta here is estimated by hand
theta = (16, 4.0)
x = np.linspace(0.1, 3, 50)
plt.plot(x, theta[0]/x + theta[1], '--', c='r', lw=2);

# %% [markdown]
# From the above plot we can deduce that the fare charges has a wider variance/spread for the shorter trips (< 1 mile) compared to longer trips (> 1 mile). A factor that causes this could be the fact that the distance for trips is measured by point-to-point and not actual roads and access routes. This difference is more significant for shorter trips especially during rush hours
# Another good assumption for this spread at shorter distance trips could be due to slow traffic/ traffic-jams during rush hours. Shorter drives during such phenomenons will vary more in duration

# %% [markdown]
# An important relationship to visualize is how the hour of the day affects the fare amount. In the next section we visualze this using pandas pivot plot

# %%
# Continuing the analysis of fare per distance vs time, create pivot tables and plot the fare charge per distance to pick up hour

# display pivot table
taxi_df.pivot_table('fare_per_mile', index='pickup_hour', columns='pickup_year').plot(figsize=(20,7))
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.grid(True)
plt.ylabel('Fare $USD / mile');

# %% [markdown]
# From the plot above we can deduce that the fare charges rise from the earlier hours of the day and peak around 12:00 pm - 13:00 pm which indicate that these might be the when the busiest hours of the day commence with much traffic. Next step to corroborate this point would be to check how the extra charges due to rush-hours influence the total charges.
# We may do this using the 'Extra' feature column in the dataframe which contains boolean values that indicate when these charges are applied in the trips.

# %%
# display pivot table
idx = (taxi_df['Extra'] == True)
taxi_df[idx]['pickup_hour'].unique()
# Out:
# array([20, 21, 22, 23, 12, 15, 16, 17, 18, 19,  0,  1,  2,  3,  4,  5,  6,
#         8, 14])

# %%
for i in range(12, 24):
    pred = (taxi_df['pickup_hour'] == i) & (taxi_df['Extra'] == True)
    print("The number of extra charges incurred at {}:00 pm is : {:0.2f}".format(i, len(taxi_df[pred])))
# Out:
# The number of extra charges incurred at 12:00 pm is : 1.00
# The number of extra charges incurred at 13:00 pm is : 0.00
# The number of extra charges incurred at 14:00 pm is : 1.00
# The number of extra charges incurred at 15:00 pm is : 65.00
# The number of extra charges incurred at 16:00 pm is : 858.00
# The number of extra charges incurred at 17:00 pm is : 1065.00
# The number of extra charges incurred at 18:00 pm is : 1232.00
# The number of extra charges incurred at 19:00 pm is : 1329.00
# The number of extra charges incurred at 20:00 pm is : 1644.00
# The number of extra charges incurred at 21:00 pm is : 1584.00
# The number of extra charges incurred at 22:00 pm is : 1490.00
# The number of extra charges incurred at 23:00 pm is : 1261.00

# %% [markdown]
# From the results in the cell above
# - We can deduce that the Extra charges incur from 12pm on until the later hours of the day but more of the Extra charges are due to Overnight and rush-hour charges during the later hours of the day (5 - 11 pm).
# - From the results we can also see that the peak rush-hour period is between 8 - 10 pm daily

# %% [markdown]
# ### Location Analysis
#
# In the following sections we attempt to understand the relationship between the pickup/dropoff locations and fare amount. The aim is to measure how different locations in NYC affect the fare amount and to visualize such relationships if they exist.

# %% [markdown]
# First,we visualize the relationship between trip direction and fare amount by zooming in to Manhattan

# %%
# Check to see how the direction of the trip relates to the amount of the fair charge

# function to select polygons within a provided bounding box range
def select_within_boundingbox(df, BB):
    return (df.pickup_longitude >= BB[0]) & (df.pickup_longitude <= BB[1]) & \
        (df.pickup_latitude >= BB[2]) & (df.pickup_latitude <= BB[3]) & \
        (df.dropoff_longitude >= BB[0]) & (df.dropoff_longitude <= BB[1]) & \
        (df.dropoff_latitude >= BB[2]) & (df.dropoff_latitude <= BB[3])

taxi_df['delta_longitude'] = taxi_df.pickup_longitude - taxi_df.dropoff_longitude
taxi_df['delta_latitude'] = taxi_df.pickup_latitude - taxi_df.dropoff_latitude

# Select trips in Manhattan
BB_manhattan = (-74.025, -73.925, 40.7, 40.8)
pred_manhattan = select_within_boundingbox(taxi_df, BB_manhattan)

plt.figure(figsize=(15,7))
plt.scatter(taxi_df[pred_manhattan].delta_longitude, taxi_df[pred_manhattan].delta_latitude, s=2, alpha=1.0,
            c=np.log1p(taxi_df[pred_manhattan].fare_amount), cmap='Reds')
plt.colorbar()
plt.xlabel('pickup_longitude - dropoff_longitude')
plt.ylabel('pickup_latitude - dropoff_latidue')
plt.title('log1p(fare_amount)');
# Out:
# /Users/divinefavourodion/Documents/Data_Analytics_Project/venv/lib/python3.10/site-packages/pandas/core/arraylike.py:364: RuntimeWarning:
#
# invalid value encountered in log1p

# %% [markdown]
# We can clearly see from the plot that the direction of the trip influences the fare amount, but it is not precisely clear just how much it does. In the proceeding steps, we will calculate the precise direction in degrees and plot against the fare amount.

# %% [markdown]
# So far, from the results of our analysis we have concretely determined that;
#  1. The direction of the trip influences the fare amount
# 2. There are some fixed fare amount trips despite trip distance which may likely be trips to and fro airports in New york
# Next, to aid in the modeling phase a good idea is to remove the trips to/fro the airports as they will most likely not help in explaining how the fare amount varies with respect to trip distance. To do this we would need to create Geolocation data from the coordinate columns in the dataframe.
# According to [this website](https://www.travelandleisure.com/airlines-airports/new-york-city-airports#:~:text=New%20York%20City%20has%20three,before%20booking%20your%20next%20flight.) there are 3 airports in New york;
# - John F. Kennedy International (JFK)
# - Laguardia (LGA)
# - Newark Liberty International (EWR)
# We will aim to remove trips to these 3 locations from our dataset

# %% [markdown]
# The section below visualizes how the fare amount  varies with  pick up location. To do that we can calculate the distance from the pick-up location using the pick-up latitude and longitude values to the NYC city center

# %%
# Gotten from https://stackoverflow.com/questions/27928/
# Function to calculate the distance between two longitude - latitude points using haversine-formula

def distance(lat_1, lon_1, lat_2, lon_2):
    p = 0.017453292519943295 # Pi/180
    a = 0.5 - np.cos((lat_2 - lat_1) * p)/2 + np.cos(lat_1 * p) * np.cos(lat_2 * p) * (1 - np.cos((lon_2 - lon_1) * p)) / 2
    return 0.6213712 * 12742 * np.arcsin(np.sqrt(a))

nyc = (-74.0063889, 40.7141667) # Longitude and Latitude pair for Nyc center

# add new column to dataframe with distance in mile to the city center
taxi_df['dist_center'] = distance(nyc[1], nyc[0], taxi_df.pickup_latitude, taxi_df.pickup_longitude)

# %% [markdown]
# To visualize this complex relationship we will plot the distance to the city center vs the distance of the entire trip vs the fare amount, but first we check for rogue instances in the data with recorded distances beyond the boundaries of New york

# %%
taxi_df.dist_center.describe()
# Out:
# count    28275.000000
# mean        79.023433
# std        633.258780
# min          0.012803
# 25%          2.026748
# 50%          3.204956
# 75%          4.534858
# max       5385.503914
# Name: dist_center, dtype: float64

# %% [markdown]
# From the table we can see that some unrealistic distances are recorded in the data. The max distance to the NYC city center is over 5000 miles which doesn't make any sense as the size of Newyork is only 302.6 sq miles (from  [google.com](https://www.google.com.)). Let's take a closer look at the rows in the dataframe having such large values.

# %%
pred = (taxi_df.dist_center > 302)
taxi_df[pred]
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 8             1  2016-02-19 20:59:02   2016-02-19 21:25:50                3
# 45            1  2016-02-19 21:28:55   2016-02-19 21:36:49                1
# 134           1  2016-02-19 22:45:47   2016-02-19 23:02:10                1
# 173           1  2016-02-19 23:15:40   2016-02-19 23:23:33                1
# 476           1  2016-02-01 13:41:39   2016-02-01 14:00:50                1
# ...         ...                  ...                   ...              ...
# 27908         2  2016-02-27 21:36:18   2016-02-27 21:42:15                1
# 27936         2  2016-02-27 22:21:47   2016-02-27 22:41:58                1
# 27991         2  2016-02-28 00:01:03   2016-02-28 00:16:28                2
# 28286         2  2016-02-28 16:11:18   2016-02-28 16:21:03                4
# 28327         2  2016-02-28 17:34:50   2016-02-28 17:39:08                5
#
# ...

# %% [markdown]
# From the above table we have discovered some rogue entries with pick_up longitude and pick_up latitude of 0 which make no sense as there are no where close to New york city located at (-74.0063889, 40.7141667) according to [this website](https://www.travelmath.com/cities/New+York,+NY.). To aid our analysis, we proceed by dropping such rows

# %%
print('Old size: %d' % len(taxi_df))
taxi_df = taxi_df[~pred]
print('New size: %d' % len(taxi_df))
# Out:
# Old size: 28275
# New size: 27878

# %% [markdown]
# Next, we plot the distance to the city center vs the distance of the entire trip vs the fare amount

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,7))
im = axs[0].scatter(taxi_df.dist_center, taxi_df.trip_distance, c=np.clip(taxi_df.fare_amount, 0, 100),
                    cmap='plasma', alpha=1.0, s=1)
axs[0].set_xlabel('pickup distance from NYC center')
axs[0].set_ylabel('distance in miles')
axs[0].set_title('For all of the Data')
cbar = fig.colorbar(im, ax=axs[0])
cbar.ax.set_ylabel('fare_amount', rotation=270)

pred = (taxi_df.dist_center < 15) & (taxi_df.trip_distance < 35)
im = axs[1].scatter(taxi_df[pred].dist_center, taxi_df[pred].trip_distance,
                    c=np.clip(taxi_df[pred].fare_amount, 0, 100), cmap='plasma', alpha=1.0, s=1)
axs[1].set_xlabel('pickup distance from NYC center')
axs[1].set_ylabel('distance miles')
axs[1].set_title('Zoom in to trips less than 35 miles and with pick up locations less than 15 miles from the center')
cbar = fig.colorbar(im, ax=axs[1])
cbar.ax.set_ylabel('fare_amount', rotation=270);

# %% [markdown]
# A check on Google maps puts the distance from the JFK international airport to the city center at approximately 21.25 km which converts to 13.20 miles. When we look at the plots above there is a cluster of fare amounts around the 60 USD - 70 USD range right about the 13 mile point on pick up distance from NYC axis (x_axis).
#
# In the next step we eliminate such points from the dataset and view the plots again

# %%
jfk = (-73.7822222222, 40.6441666667) # Longitude and latitude pair for JFK airport

taxi_df['pickup_dist_to_jfk'] = distance(jfk[1], jfk[0], taxi_df.pickup_latitude, taxi_df.pickup_longitude)
taxi_df['dropoff_dist_to_jfk'] = distance(jfk[1], jfk[0], taxi_df.dropoff_latitude, taxi_df.dropoff_longitude)

# %%
pred = ~((taxi_df['pickup_dist_to_jfk'] < 1) | (taxi_df['pickup_dist_to_jfk'] < 1)) # Removing trips to/fro JFK airport
taxi_df = taxi_df[pred]

fig, axs = plt.subplots(1, 2, figsize=(15,7))
im = axs[0].scatter(taxi_df.dist_center, taxi_df.trip_distance, c=np.clip(taxi_df.fare_amount, 0, 100),
                    cmap='plasma', alpha=1.0, s=1)
axs[0].set_xlabel('pickup distance from NYC center')
axs[0].set_ylabel('distance in miles')
axs[0].set_title('For all of the Data')
cbar = fig.colorbar(im, ax=axs[0])
cbar.ax.set_ylabel('fare_amount', rotation=270)

pred = (taxi_df.dist_center < 15) & (taxi_df.trip_distance < 35)
im = axs[1].scatter(taxi_df[pred].dist_center, taxi_df[pred].trip_distance,
                    c=np.clip(taxi_df[pred].fare_amount, 0, 100), cmap='plasma', alpha=1.0, s=1)
axs[1].set_xlabel('pickup distance from NYC center')
axs[1].set_ylabel('distance miles')
axs[1].set_title('Zoom in to trips less than 35 miles and with pick up locations less than 15 miles from the center')
cbar = fig.colorbar(im, ax=axs[1])
cbar.ax.set_ylabel('fare_amount', rotation=270);

# %% [markdown]
# The resulting visualization shows that the cluster of fixed price trips have been removed and the relationship seems more linear so, we should apply the same filtering for the other two airports in New york

# %%
ewr = (-74.175, 40.69) # Newark Liberty International Airport,
lgr = (-73.87, 40.77) # LaGuardia Airport

taxi_df['pickup_dist_to_ewr'] = distance(ewr[1], ewr[0], taxi_df.pickup_latitude, taxi_df.pickup_longitude)
taxi_df['dropoff_dist_to_ewr'] = distance(ewr[1], ewr[0], taxi_df.dropoff_latitude, taxi_df.dropoff_longitude)
taxi_df['pickup_dist_to_lgr'] = distance(lgr[1], lgr[0], taxi_df.pickup_latitude, taxi_df.pickup_longitude)
taxi_df['dropoff_dist_to_lgr'] = distance(lgr[1], lgr[0], taxi_df.dropoff_latitude, taxi_df.dropoff_longitude)


# remove all to/from airport trips
pred = ~((taxi_df.pickup_dist_to_ewr < 1) | (taxi_df.dropoff_dist_to_ewr < 1) |
        (taxi_df.pickup_dist_to_lgr < 1) | (taxi_df.dropoff_dist_to_lgr < 1))

print('Old size: %d' % len(taxi_df))
taxi_df = taxi_df[pred]
print('New size: %d' % len(taxi_df))
# Out:
# Old size: 27341
# New size: 26312

# %%
# Plot the data

pred = ~((taxi_df['pickup_dist_to_jfk'] < 1) | (taxi_df['pickup_dist_to_jfk'] < 1)) # Removing trips to/fro JFK airport
taxi_df = taxi_df[pred]

fig, axs = plt.subplots(1, 2, figsize=(15,10))
im = axs[0].scatter(taxi_df.dist_center, taxi_df.trip_distance, c=np.clip(taxi_df.fare_amount, 0, 100),
                    cmap='plasma', alpha=1.0, s=1)
axs[0].set_xlabel('pickup distance from NYC center')
axs[0].set_ylabel('distance in miles')
axs[0].set_title('For all of the Data')
cbar = fig.colorbar(im, ax=axs[0])
cbar.ax.set_ylabel('fare_amount', rotation=270)

pred = (taxi_df.dist_center < 15) & (taxi_df.trip_distance < 35)
im = axs[1].scatter(taxi_df[pred].dist_center, taxi_df[pred].trip_distance,
                    c=np.clip(taxi_df[pred].fare_amount, 0, 100), cmap='plasma', alpha=1.0, s=1)
axs[1].set_xlabel('pickup distance from NYC center')
axs[1].set_ylabel('distance miles')
axs[1].set_title('Zoom in to trips less than 35 miles and with pick up locations less than 15 miles from the center')
cbar = fig.colorbar(im, ax=axs[1])
cbar.ax.set_ylabel('fare_amount', rotation=270);

# %% [markdown]
# After filtering for fixed distance trips the relationship seems even more linear and we can clearly deduce that the fare amount depends more on the distance travelled and less on the starting point of the trips.

# %% [markdown]
# ## Transformations

# %% [markdown]
# In this section of  our data preparation, we classify the features in the dataset based on their data types. In order to train machine learning models it is mandatory to convert categorical and non-numeric data types to numeric for the ml algorithms to be able to interpret

# %%
 taxi_df.shape # Check the shape of the dataset
# Out:
# (26312, 43)

# %%
taxi_df.dtypes # List the data types of each feature
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# pickup_longitude                float64
# pickup_latitude                 float64
# RatecodeID                        int64
# store_and_fwd_flag               object
# dropoff_longitude               float64
# dropoff_latitude                float64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# GoodTip                            bool
# Extra                              bool
# Cash                               bool
# pickup_time                      object
# ...

# %% [markdown]
# The resulting dataset from the data cleaning anf EDA phase has a shape of 26,312 rows and 42 columns. It still contains some columns with categorical features which require transformations before passing into a machine learning or statistical model. Our categoical feature columnns are;
# 1. VendorID
# 2. RatecodeID
# 3. store_and_fwd_flag
# 4. payment_type
# 5. GoodTip
# 6. Extra
# 7. Cash
# In the next steps we will transform these columns using the LabelEncoder class from sklearn so that we can use them in the feature engineering / feature selection phase

# %%
l_encoder = LabelEncoder() # Label Encoder class

column_list = ['VendorID', 'RatecodeID', 'store_and_fwd_flag', 'payment_type', 'GoodTip', 'Extra', 'Cash']

for name in column_list:
    l_encoder.fit(taxi_df[name])
    taxi_df[name] = l_encoder.transform(taxi_df[name])
taxi_df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2016-02-07 16:20:16   2016-02-07 16:25:24                1
# 1             1  2016-02-07 16:20:29   2016-02-07 16:33:41                1
# 2             0  2016-02-19 20:54:40   2016-02-19 21:02:02                1
# 3             0  2016-02-19 20:55:23   2016-02-19 21:05:03                2
# 4             1  2016-02-19 20:56:06   2016-02-19 21:01:03                5
# ...         ...                  ...                   ...              ...
# 28447         1  2016-02-28 23:26:57   2016-02-28 23:30:51                1
# 28448         1  2016-02-28 23:34:34   2016-02-28 23:49:55                1
# 28450         1  2016-02-28 23:48:32   2016-02-29 00:10:57                1
# 28452         1  2016-02-28 23:55:24   2016-02-29 00:02:03                2
# 28453         1  2016-02-29 00:01:48   2016-02-29 00:04:20                1
#
# ...

# %% [markdown]
# This concludes the data cleaning and Exploratory Data Analysis (EDA) phase of this experiment. In the second part of this report we begin training and evaluating different algorithms on the dataset to determine the best model based on selected error metrics and predetermined thresholds.

# %% [markdown]
# # Modeling

# %% [markdown]
# In this second part of the experiment we will begin with a baseline linear regression model to explore all features and determine the best predictors of the dependent variable 'Fare amount'.

# %%
taxi_df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RatecodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount', 'GoodTip', 'Extra', 'Cash',
#        'pickup_time', 'pickup_day', 'pickup_month', 'pickup_year',
#        'dropoff_time', 'dropoff_day', 'dropoff_month', 'dropoff_year',
#        'weekday', 'pickup_hour', 'dropoff_hour', 'fare_per_mile',
#        'delta_longitude', 'delta_latitude', 'dist_center',
#        'pickup_dist_to_jfk', 'dropoff_dist_to_jfk', 'pickup_dist_to_ewr',
#        'dropoff_dist_to_ewr', 'pickup_dist_to_lgr', 'dropoff_dist_to_lgr'],
#       dtype='object')

# %% [markdown]
#  From our data let's define a base data set to use for modelling, dropping all additional columns that were created during the EDA phase and columns that do not relate in any way to the fair amount (target variable).
#
#  Also we would like to drop all columns containing data that simply would not be available if the model is deployed in real-time. This is because we aim to come as close as possible to a model that can be deployed in the real world
#
#  Below is a list of baseline features to begin modelling with;

# %%
# List of features for baseline model
column_list = ['VendorID', 'passenger_count', 'trip_distance', 'pickup_longitude', 'pickup_latitude', 'RatecodeID', 'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount', 'Cash', 'pickup_day', 'pickup_month', 'pickup_year', 'dropoff_day', 'dropoff_month', 'dropoff_year', 'weekday', 'pickup_hour', 'dropoff_hour','delta_longitude', 'delta_latitude']


taxi_copy = taxi_df[column_list] # Reduced feature columns for modelling
taxi_copy
# Out:
#        VendorID  passenger_count  trip_distance  pickup_longitude  \
# 0             1                1           1.04        -73.956322
# 1             1                1           2.78        -73.987045
# 2             0                1           2.40        -73.975731
# 3             0                2           1.90        -73.961922
# 4             1                5           0.47        -74.002571
# ...         ...              ...            ...               ...
# 28447         1                1           0.82        -73.972549
# 28448         1                1           9.07        -73.987480
# 28450         1                1           5.90        -74.006958
# 28452         1                2           1.50        -73.988831
# 28453         1                1           0.65        -73.983673
#
#        pickup_latitude  RatecodeID  dropoff_longitude  dropoff_latitude  \
# 0            40.781319           0         -73.960297         40.769520
# ...

# %%
# Define the training data and specify target variable
X = taxi_copy.drop(columns=['fare_amount'])
y = taxi_copy['fare_amount'].values

print(X.shape)
print(y.shape)
# Out:
# (26312, 21)
# (26312,)

# %% [markdown]
# Next, we split the data into train and test sets with the ratio 70% to 30%

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
taxi_copy.dtypes # Check to verify that all features are of a numeric datatype
# Out:
# VendorID               int64
# passenger_count        int64
# trip_distance        float64
# pickup_longitude     float64
# pickup_latitude      float64
# RatecodeID             int64
# dropoff_longitude    float64
# dropoff_latitude     float64
# payment_type           int64
# fare_amount          float64
# Cash                   int64
# pickup_day             int64
# pickup_month           int64
# pickup_year            int64
# dropoff_day            int64
# dropoff_month          int64
# dropoff_year           int64
# weekday                int64
# pickup_hour            int64
# dropoff_hour           int64
# delta_longitude      float64
# delta_latitude       float64
# dtype: object

# %% [markdown]
# Next, we define a training pipeline to apply standardization to the selected features for the linear model and then to fit the model on the standardized data to use for predicting the test set. Standardization is a scaling method applied in data analytics and modelling used to put variables in a dataset on the same scale (with a mean of 0 and standard deviation of 1) so that they contribute equally during modelling. If the input variables to a machine learning model are not scaled it could sometimes be the result that variable/feature columns with higher units will be unfairly given higher weightage compared to the rest.

# %%
model_pipe = Pipeline((
    ("standard_scaler", StandardScaler()),
    ("lin_reg", LinearRegression()),
)) # Pipeline for feature scaling through standardization and to fit a linear regression model
model_pipe.fit(X_train, y_train) # Fit the linear model on the data

y_train_pred = model_pipe.predict(X_train) # Predict the training set
y_test_pred = model_pipe.predict(X_test)# Predict the test set

# %% [markdown]
# Next, we define some functions for visualizing the prediction errors using RMSE

# %%
# Function for visualizing the Rmse, evs and a histogram plot of the prediction errors
def plot_prediction_analysis(y, y_pred, figsize=(10,4), title=''):
    fig, axs = plt.subplots(1, 2, figsize=figsize)
    axs[0].scatter(y, y_pred)
    mn = min(np.min(y), np.min(y_pred))
    mx = max(np.max(y), np.max(y_pred))
    axs[0].plot([mn, mx], [mn, mx], c='red')
    axs[0].set_xlabel('$y$')
    axs[0].set_ylabel('$\hat{y}$')
    rmse = np.sqrt(mean_squared_error(y, y_pred))
    evs = explained_variance_score(y, y_pred)
    axs[0].set_title('rmse = {:.2f}, evs = {:.2f}'.format(rmse, evs))

    axs[1].hist(y-y_pred, bins=50)
    avg = np.mean(y-y_pred)
    std = np.std(y-y_pred)
    axs[1].set_xlabel('$y - \hat{y}$')
    axs[1].set_title('Histrogram prediction error, $\mu$ = {:.2f}, $\sigma$ = {:.2f}'.format(avg, std))

    if title!='':
        fig.suptitle(title)

# %%
plot_prediction_analysis(y_train, y_train_pred, title='Linear Model - Trainingset')

# %%
plot_prediction_analysis(y_test, y_test_pred, title='Linear Model - Testset')

# %% [markdown]
# From the results above, using a baseline linear regression model with the selected features produces an average rmse of 2.83 which already denotes a good model for the data, but we can validate our model better using other error metrics.
# To achieve this, another good error metric for evaluating our baseline model is the Mean Absolute Percentage error (MAPE) defined by the formula;
#
#
#
# ![Mape Formula](images/mape_formula.png)
#
# where
#
# M = Mean Absolute Percentage Error
# n = The number of times the summation occurred
# At = Actual value
# Ft = Forecast value
#
# MAPE is one of the most popular methods for assessing the performance of machine learning forecasting models.

# %%
# Define function for computing MAPE
def mape(Y_actual,Y_Predicted):
    Y_actual = np.array(Y_actual)
    Y_Predicted = np.array(Y_Predicted)
    mape = []
    mape.append((np.abs((Y_actual - Y_Predicted)/Y_actual))*100)
    return mape

# %%
# Compute the mape on the test set
mape_errors = mape(y_test, y_test_pred)
mape_errors
# Out:
# [array([42.83842507, 21.59207553, 17.62921114, ..., 24.93254269,
#          8.75696765,  4.95116952])]

# %% [markdown]
# Now that we've computed the MAPE on the test set, let's check for outlier errors above a reasonable threshold of 50%. This will enable us determine how much the linear regression model produces predictions that are too far off to be even considered.

# %%
outliers = []
[outliers.append(x) for x in mape_errors[0] if x >= 50]
print('The number of predictions made with MAPE above 50% reasonable threshold is {} out of {} predictions made on the test set '.format(len(outliers), len(y_test)))
# Out:
# The number of predictions made with MAPE above 50% reasonable threshold is 261 out of 7894 predictions made on the test set

# %% [markdown]
# From the above result we can say that we have achieved a fairly good model that only makes prediction with >= 50% errors 3% of the time.

# %% [markdown]
# Next, we remove the outliers to visualize how good our linear model is

# %%
filtered_data = [v for v in mape_errors[0] if  v <= 50]

# %%
# Plot the errors against time
fig = plt.figure(figsize=(20,10))
plt.hist(filtered_data, bins=50)
plt.grid(True)
plt.xlabel('Mape Errors')
plt.ylabel('Occurences')
plt.title('MAPE on the test set using a linear regression model')
ax = plt.gca()
# ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
plt.show()

# %% [markdown]
# From the figure above we can evaluate the performance of the model better. If we set a MAPE threshold of 20% we can see from the plot that over 50 -60 % of the model predictions on the test set fall below this threshold. Therefore, we can say that we have a solid baseline to improve upon.
#
# So far, we have explored a linear regression model for prediction, let's build upon this by exploring more complex algorithms. In the next sections we will train a couple of machine learning models as well to select a best performer.

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Before training machine learning algorithms, we can perform some preliminary feature selection using a linear regression model implementing Ordinary least squares (OLS) to evaluate the best independent variables that explain the target/dependent variable. OLS compares the difference between individual points in the data set and the predicted best fit line to measure the amount of error produced according to [this article](https://medium.com/swlh/interpreting-linear-regression-through-statsmodels-summary-4796d359035a.)

# %%
# Using the statsmodel.api library
eval_model = sm.OLS(y, exog= X)
results = eval_model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.884
# Method:                 Least Squares   F-statistic:                 1.252e+04
# Date:                Sat, 10 Dec 2022   Prob (F-statistic):               0.00
# Time:                        15:44:47   Log-Likelihood:                -62411.
# No. Observations:               26312   AIC:                         1.249e+05
# Df Residuals:                   26295   BIC:                         1.250e+05
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# VendorID             -0.1292      0.034     -3.848      0.000      -0.195      -0.063
# ...

# %% [markdown]
# Interpretation of the Results:
# 1. The R squared metric is a measure of how much of the change in the dependent variable is explained by the independent variables. From our results we can deduce that 88.4% of the fare amount is explained by our selected features
# 2. The adjusted R squared is metric to penalize the R squared metric based on the number of independent variables as linear regression has the characteristic that the R squared tends to increase or stay the same as additional features are added to the model. From our results, the adjusted R squared is the same as the R squared which indicates that none of the independent variables constitute noise for the model.
# 3. The Prob (F-statistic) tells us the accuracy of the null hypothesis which is how true the independent variables' effect on our model is zero. From our results, it indicates that there is 0% chance that the effect of the dependent variables is zero which is a good result.
# 4. P > |t| or p-value tells us how likely the coefficient is measured through the model by chance. Using the coefficient with the largest p-value 'passenger_count', it tells us that there a 61.7% chance that the passenger count has no effect on the fare amount. This result makes sense because in reality the number of passengers during a ride usually does not affect the amount charged at the end of the trip. This site [here](https://www.nyc.gov/site/tlc/passengers/taxi-fare.page.) corroborates this finding.
#
#
#
# From the results of this preliminar feature selection approach we can proceed by dropping the 'passenger_count' feature from our training data.

# %%
taxi_copy.drop(columns=['passenger_count'], inplace=True)
taxi_copy
# Out:
#        VendorID  trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0             1           1.04        -73.956322        40.781319           0
# 1             1           2.78        -73.987045        40.720921           0
# 2             0           2.40        -73.975731        40.758167           0
# 3             0           1.90        -73.961922        40.779140           0
# 4             1           0.47        -74.002571        40.739639           0
# ...         ...            ...               ...              ...         ...
# 28447         1           0.82        -73.972549        40.756130           0
# 28448         1           9.07        -73.987480        40.765659           0
# 28450         1           5.90        -74.006958        40.729401           0
# 28452         1           1.50        -73.988831        40.743351           0
# 28453         1           0.65        -73.983673        40.766930           0
#
# ...

# %% [markdown]
# In this step we will plot a correlation matrix to expose any Multi-collinearity between features in our current training set. Multi-collinearity is a phenomenon where two or more features in the training data are exactly correlated. This is harmful during modeling because the regression coefficients are not unique and this impairs the model's interpretability.
#
# Let's make a correlation matrix using pandas .corr() method that implements pearson's r for linear correlation
#
# Note, we will need to exclude 4 feature columns for this correlation plot that offer no information to the model
#
# 1. The pick up year because we only have data roughly for a single year and no seasonal analysis can be generated from this
# 2. The drop off year also for the above reason
# 3. The pick up month because we only have data for February
# 4. The dropoff month for the above reason as well

# %%
print(taxi_copy['pickup_month'].unique())
print(taxi_copy['pickup_year'].unique())
print(taxi_copy['dropoff_month'].unique())
print(taxi_copy['dropoff_year'].unique())
# Out:
# [2]
# [2016]
# [2 3]
# [2016]

# %% [markdown]
# The four columns above will be dropped from the training data

# %%
taxi_copy.drop(columns=['pickup_month', 'pickup_year', 'dropoff_year', 'dropoff_month'], inplace=True)

# %%
plt.figure(figsize=(20, 10))
corrplot = taxi_copy.corr()
sns.heatmap(corrplot, annot=True)
plt.show()

# %% [markdown]
# From the Correlation plot we can clearly see that;
# 1. The trip_distance feature has the highest correlation with the fare amount with a value of 0.93
# 2. The payment type and Cash feature columns have a high correlation value of 0.96 which could be a sign of Multi-collinearity
#
#
# These are the most important insights gained from the correlation plots

# %% [markdown]
# Next we drop the 'payment_type' feature because it is slightly less correlated with the target variable 'fare amount' than the Cash feature to eliminate Collinearity

# %%
taxi_copy.drop(columns=['payment_type'], inplace=True)
taxi_copy
# Out:
#        VendorID  trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0             1           1.04        -73.956322        40.781319           0
# 1             1           2.78        -73.987045        40.720921           0
# 2             0           2.40        -73.975731        40.758167           0
# 3             0           1.90        -73.961922        40.779140           0
# 4             1           0.47        -74.002571        40.739639           0
# ...         ...            ...               ...              ...         ...
# 28447         1           0.82        -73.972549        40.756130           0
# 28448         1           9.07        -73.987480        40.765659           0
# 28450         1           5.90        -74.006958        40.729401           0
# 28452         1           1.50        -73.988831        40.743351           0
# 28453         1           0.65        -73.983673        40.766930           0
#
# ...

# %% [markdown]
# In the next step, we proceed to train two tree-based models that implement gradient boosting and gradient bagging which are ensemble learning methods. Gradient bagging is an ensemble learning approach where several weak learners (trees) are trained on bootstrapped samples of the training data and where a prediction is given as the average prediction of all weak learners in parallel. Gradient boosting on the other hand entails training several weak learners in a sequential way where learners (trees) attempt to correct the errors of previous learners until a final output is produced. We aim to compare and contrast against both of these methods to see which performs better. Our models are;
# 1. Random forest (Gradient bagging)
# 2. Catboost (Gradient boosting)

# %% [markdown]
# ## Random Forest

# %% [markdown]
# Since we have reduced the feature columns down to 16 features since last time we need to define and split the train and test sets again

# %%
# Define the training data
X = taxi_copy.drop(columns=['fare_amount'])
y = taxi_copy['fare_amount'].values

print(X.shape)
print(y.shape)
# Out:
# (26312, 15)
# (26312,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # Split into train and test sets

# %% [markdown]
# ### Grid Search

# %% [markdown]
# To pick the best estimator we apply a Grid search algorithm over the training data and select the most relevant hyper-parameters for model tuning. These are;
#
# 1. max_depth: The maximum depth of the tree
# 2. max_features: The number of features to consider when searching for the best split
# 3. n_estimators: The number of weak learners (trees) to use in the model

# %%
print('The size of the training set is {}'.format(X_train.shape))
print('The size of the test set is {}'.format(X_test.shape))
# Out:
# The size of the training set is (18418, 15)
# The size of the test set is (7894, 15)

# %%
# Grid search
model = RandomForestRegressor()
parameters = {'max_depth' : sp_randInt(1, 10),
              'max_features': sp_randInt(1, 15),
              'n_estimators' : sp_randInt(10, 1000),
              }
randm = RandomizedSearchCV(estimator=model, param_distributions=parameters, cv=2, n_iter=10, n_jobs=-1)
randm.fit(taxi_copy, y)

print("\n *********************************************")
print("Results from random search")
print("************************************************")
print("\n The best estimator across ALL searched params:\n", randm.best_estimator_)
print("\n The best score across ALL searched params:\n", randm.best_score_)
print("\n The best parameters across ALL searched params:\n", randm.best_params_)
print("\n *********************************************")
# Out:
#  *********************************************
# Results from random search
# ************************************************
#
#  The best estimator across ALL searched params:
#  RandomForestRegressor(max_depth=7, max_features=12, n_estimators=576)
#
#  The best score across ALL searched params:
#  0.992330072969021
#
#  The best parameters across ALL searched params:
#  {'max_depth': 7, 'max_features': 12, 'n_estimators': 576}
#
#  *********************************************

# %% [markdown]
# The results of the Grid search gave {'max_depth': 7, 'max_features': 12, 'n_estimators': 576} as the hyper-parameters corresponding to the model with the best fit on the data. So we will select this model and evaluate on our test set.

# %%
forest_model = RandomForestRegressor(n_estimators = 576, max_depth= 7, max_features=12, n_jobs = -1)
forest_model.fit(X_train.values , y_train)
forest_model.feature_importances_
# Out:
# array([2.69106295e-04, 8.24630605e-01, 2.65555965e-03, 1.04219435e-03,
#        8.83026618e-02, 7.68067930e-03, 3.41496319e-03, 2.73969577e-04,
#        1.01111466e-03, 1.02668292e-03, 2.37807797e-03, 3.87482838e-03,
#        4.33201111e-03, 3.73238039e-02, 2.17837420e-02])

# %%
feat_dict = {'Feature Names': X_train.columns,'Importances': forest_model.feature_importances_}
feat_importances = pd.DataFrame.from_dict(feat_dict)
feat_importances
# Out:
#         Feature Names  Importances
# 0            VendorID     0.000269
# 1       trip_distance     0.824631
# 2    pickup_longitude     0.002656
# 3     pickup_latitude     0.001042
# 4          RatecodeID     0.088303
# 5   dropoff_longitude     0.007681
# 6    dropoff_latitude     0.003415
# 7                Cash     0.000274
# 8          pickup_day     0.001011
# 9         dropoff_day     0.001027
# 10            weekday     0.002378
# 11        pickup_hour     0.003875
# 12       dropoff_hour     0.004332
# 13    delta_longitude     0.037324
# 14     delta_latitude     0.021784

# %% [markdown]
# We have fit the random forest model on the data. Now we can take a look at the most important features of the model using the .feature_importance_ function.
# - Again, here we see that the trip distance is the most important feature for predicting the fare amount
# - The least important feature is the CASH boolean (initially before transformation to binary feature).
#
# The analysis is important because it will help in selecting a smaller subset of features based on the model's feature importances that may improve model performance.

# %% [markdown]
# Next, we evaluate the random forest model on the test dataset

# %%
y_train_pred_rand = forest_model.predict(X_train)
y_test_pred_rand= forest_model.predict(X_test)

# %%
plot_prediction_analysis(y_train, y_train_pred_rand, title='Random forest Model - Trainingset')

# %%
plot_prediction_analysis(y_test, y_test_pred_rand, title='Random forest Model - Testset')

# %% [markdown]
# Already we can see an improvement on the linear model with a decrease in the average rmse on the test set from 2.56 to 2.09. Next we will also evaluate the model on the test set using MAPE as the key metric.
#
# Next, we compute the MAPE on the test set.

# %%
mape_errors_rand = mape(y_test, y_test_pred_rand)
mape_errors_rand
# Out:
# [array([ 3.68726077,  1.90313462, 11.20363758, ...,  0.76615213,
#         21.33897375,  7.84985243])]

# %%
max(mape_errors_rand[0])
# Out:
# 725.1789459321711

# %% [markdown]
# It seems we have some predictions (outliers) with MAPE too large so to visualize we would need to remove errors that are too large. We suspect these will be very few points in the data as seen in the linear model.

# %%
outliers = []
[outliers.append(x) for x in mape_errors_rand[0] if x >= 50]
print('The number of predictions made with MAPE above 50% reasonable threshold is {} out of {} predictions made on the test set '.format(len(outliers), len(y_test)))
# Out:
# The number of predictions made with MAPE above 50% reasonable threshold is 19 out of 7894 predictions made on the test set

# %% [markdown]
# Examining the MAPE on the test set, we can see that the random forest model out performs the Linear model in the case of outlier predictions with errors above the 50% reasonable threshold. In the next step we drop those outliers to visualize the model performance better.

# %%
# Remove outlier errors
filtered_data = [v for v in mape_errors_rand[0] if  v <= 50]

# %%
# Plot the MAPE errors
fig = plt.figure(figsize=(20,10))
plt.hist(filtered_data, bins=50)
plt.grid(True)
plt.xlabel('Mape Errors')
plt.ylabel('Occurences')
plt.title('MAPE on the test set using a Random forest model')
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
plt.show()

# %% [markdown]
# From the above visualization we can see an improvement in the predictions as approximately over 90% of the predicted fare amount for our test set fall under our previously set threshold of 20%.

# %% [markdown]
# ## Catboost

# %% [markdown]
# Next, we train a catboost model and evaluate on the test set as we did for the Random forest model

# %% [markdown]
# ### Grid search

# %%
# Grid search
model = CatBoostRegressor()
parameters = {'depth' : sp_randInt(1, 10),
              'learning_rate' : sp_randFloat(),
              'n_estimators' : sp_randInt(10, 1000),
              'l2_leaf_reg' : sp_randInt(1, 10)
              }
randm = RandomizedSearchCV(estimator=model, param_distributions=parameters, cv=2, n_iter=10, n_jobs=-1)
randm.fit(taxi_copy, y)

print("\n *********************************************")
print("Results from random search")
print("************************************************")
print("\n The best estimator across ALL searched params:\n", randm.best_estimator_)
print("\n The best score across ALL searched params:\n", randm.best_score_)
print("\n The best parameters across ALL searched params:\n", randm.best_params_)
print("\n *********************************************")
# Out:
# 0:	learn: 4.6072038	total: 63.9ms	remaining: 34.3s
# 1:	learn: 3.0157299	total: 66.2ms	remaining: 17.7s
# 2:	learn: 2.1854765	total: 89.2ms	remaining: 15.9s
# 3:	learn: 1.7425746	total: 92.2ms	remaining: 12.3s
# 4:	learn: 1.6607581	total: 94.8ms	remaining: 10.1s
# 5:	learn: 1.4529853	total: 96.3ms	remaining: 8.54s
# 6:	learn: 1.4158000	total: 97.6ms	remaining: 7.41s
# 7:	learn: 1.3814364	total: 101ms	remaining: 6.67s
# 8:	learn: 1.3517838	total: 105ms	remaining: 6.16s
# 9:	learn: 1.3255332	total: 109ms	remaining: 5.77s
# 10:	learn: 1.1305529	total: 112ms	remaining: 5.38s
# 11:	learn: 1.1105620	total: 114ms	remaining: 4.98s
# 12:	learn: 1.0942312	total: 115ms	remaining: 4.65s
# 13:	learn: 1.0803602	total: 116ms	remaining: 4.36s
# 14:	learn: 0.9573753	total: 118ms	remaining: 4.12s
# 15:	learn: 0.8770958	total: 122ms	remaining: 3.98s
# 16:	learn: 0.8648933	total: 128ms	remaining: 3.92s
# 17:	learn: 0.8552652	total: 131ms	remaining: 3.78s
# ...

# %% [markdown]
# The results of the Grid search gave {'depth': 2, 'l2_leaf_reg': 7, 'learning_rate': 0.2633157920728729, 'n_estimators': 336} as the hyper-parameters corresponding to the model with the best fit on the data. So we will select this model and evaluate on our test set.

# %%
cat_model = CatBoostRegressor(depth = 2, l2_leaf_reg = 7, learning_rate = 0.2633157920728729, n_estimators = 336)
cat_model.fit(X_train, y_train)
# Out:
# 0:	learn: 6.1093005	total: 1.59ms	remaining: 511ms
# 1:	learn: 4.9122028	total: 3.1ms	remaining: 498ms
# 2:	learn: 4.0673475	total: 4ms	remaining: 427ms
# 3:	learn: 3.5506297	total: 4.96ms	remaining: 396ms
# 4:	learn: 3.2914703	total: 5.73ms	remaining: 365ms
# 5:	learn: 3.0408125	total: 7.21ms	remaining: 381ms
# 6:	learn: 2.9025870	total: 8.06ms	remaining: 364ms
# 7:	learn: 2.8147596	total: 9.01ms	remaining: 355ms
# 8:	learn: 2.7486887	total: 10.2ms	remaining: 354ms
# 9:	learn: 2.6903367	total: 11.2ms	remaining: 351ms
# 10:	learn: 2.6494384	total: 12.1ms	remaining: 344ms
# 11:	learn: 2.6147173	total: 12.9ms	remaining: 336ms
# 12:	learn: 2.5733807	total: 13.9ms	remaining: 331ms
# 13:	learn: 2.5479313	total: 14.9ms	remaining: 329ms
# 14:	learn: 2.5236220	total: 15.8ms	remaining: 325ms
# 15:	learn: 2.4940976	total: 16.9ms	remaining: 323ms
# 16:	learn: 2.4756076	total: 17.6ms	remaining: 316ms
# 17:	learn: 2.4591544	total: 18.5ms	remaining: 313ms
# ...

# %%
feat_dict = {'Feature Names': X_train.columns,'Importances': cat_model.feature_importances_}
feat_importances = pd.DataFrame.from_dict(feat_dict)
feat_importances
# Out:
#         Feature Names  Importances
# 0            VendorID     0.013882
# 1       trip_distance    84.660971
# 2    pickup_longitude     0.236083
# 3     pickup_latitude     0.174944
# 4          RatecodeID    10.958285
# 5   dropoff_longitude     0.319446
# 6    dropoff_latitude     0.667884
# 7                Cash     0.000000
# 8          pickup_day     0.036513
# 9         dropoff_day     0.038237
# 10            weekday     0.506912
# 11        pickup_hour     0.928645
# 12       dropoff_hour     0.566325
# 13    delta_longitude     0.195781
# 14     delta_latitude     0.696092

# %% [markdown]
# From the feature Importances of the catboost model we can also see the importance of the trip_distance feature over the rest features. It also shows that the RatecodeID is the second most important feature in the training data.
#
# The CASH feature is also the least important for the catboost model as well therefore we will drop this feature in further steps.

# %% [markdown]
# Next, we evaluate the catboost model on the test data

# %%
y_train_pred_cat = cat_model.predict(X_train)
y_test_pred_cat= cat_model.predict(X_test)

# %%
plot_prediction_analysis(y_train, y_train_pred_cat, title='Catboost Model - Trainingset')

# %%
plot_prediction_analysis(y_test, y_test_pred_cat, title='Catboost forest Model - Testset')

# %% [markdown]
# From our results it seems the catboost model improves on the rmse score on the test set from the linear model but does not outperform the random forest model. It has an rmse of 2.25 compared to 2.09.
#
# Next, we evaluate catboost on the test set using MAPE

# %%
mape_errors_cat = mape(y_test, y_test_pred_cat)
mape_errors_cat
# Out:
# [array([ 7.52544559, 11.19408117,  8.85215726, ...,  4.3817092 ,
#          3.14568947,  9.20643801])]

# %%
max(mape_errors_cat[0])
# Out:
# 857.6080192976217

# %% [markdown]
# Like for the random forest model we have some outlier predictions that are too high to visualize but the good news is that this is a minority. So to visualize, we filter the errors for errors below a set threshold like we have done for the random forest model.

# %%
filtered_data = [v for v in mape_errors_cat[0] if  v <= 50]

# %%
outliers = []
[outliers.append(x) for x in mape_errors_cat[0] if x >= 50]
print('The number of predictions made with MAPE above 50% reasonable threshold is {} out of {} predictions made on the test set '.format(len(outliers), len(y_test)))
# Out:
# The number of predictions made with MAPE above 50% reasonable threshold is 26 out of 7894 predictions made on the test set

# %% [markdown]
# The number of predictions gotten wrong with Mean Absolute percentage errors over a reasonable 50% threshold are 26 out of 7894 predictions on the test set. This indicates that we have a better model that the linear model but not quite and good as random forest.

# %%
# Visualize the MAPE
fig = plt.figure(figsize=(20,10))
plt.hist(filtered_data, bins=50)
plt.grid(True)
plt.xlabel('Mape Errors')
plt.ylabel('Occurences')
plt.title('MAPE on the test set using a Catboost model')
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
plt.show()

# %% [markdown]
# - This finding establishes random forest as our current best model for predicting the fare amount
# - In the Next steps we will attempt to tune this model and improve upon its performance.

# %% [markdown]
# ### Fine tuning

# %% [markdown]
# In this final section of this experiment, we will fine tune the best performer (random forest) to improve prediction accuracy.
# As an initial step we check the feature importance of the random forest model and eliminate features with the least relevance.

# %%
feat_dict = {'Feature Names': X_train.columns,'Importances': forest_model.feature_importances_}
feat_importances = pd.DataFrame.from_dict(feat_dict)
feat_importances
# Out:
#         Feature Names  Importances
# 0            VendorID     0.000269
# 1       trip_distance     0.824631
# 2    pickup_longitude     0.002656
# 3     pickup_latitude     0.001042
# 4          RatecodeID     0.088303
# 5   dropoff_longitude     0.007681
# 6    dropoff_latitude     0.003415
# 7                Cash     0.000274
# 8          pickup_day     0.001011
# 9         dropoff_day     0.001027
# 10            weekday     0.002378
# 11        pickup_hour     0.003875
# 12       dropoff_hour     0.004332
# 13    delta_longitude     0.037324
# 14     delta_latitude     0.021784

# %% [markdown]
# The least important features from the table above ranked accordingly include;
# 1. Cash
# 2. pickup_day
# 3. dropoff_day

# %%
# Drop irrelevant features
taxi_copy.drop(columns=['Cash', 'pickup_day', 'dropoff_day'], inplace=True)

# %%
taxi_copy.columns
# Out:
# Index(['VendorID', 'trip_distance', 'pickup_longitude', 'pickup_latitude',
#        'RatecodeID', 'dropoff_longitude', 'dropoff_latitude', 'fare_amount',
#        'weekday', 'pickup_hour', 'dropoff_hour', 'delta_longitude',
#        'delta_latitude'],
#       dtype='object')

# %% [markdown]
# #### Final feature selection

# %% [markdown]
# In this final feature selection approach we utilize sklearn's feature selection library passing our random forest model as the estimator to use in this process. The resulting feature space in this process will then be used for training a final model.
#
# If the model trained on this reduced feature space outperforms the current random forest model we will proceed with it as the best model from the experiment and if it does not perform better it would mean that in our attempt to select the best features we have lost valuable information offered from the features filtered out. In the latter case, we would revert back to the previous model as the best from the experiment

# %% [markdown]
# We specify the features to select as 11 out of the 13 passed as input to the algorithm

# %%
from sklearn.feature_selection import RFE
rfe_selector = RFE(
    estimator=RandomForestRegressor(),
    n_features_to_select= 11,
    step=20,
    verbose=5,
)

rfe_selector.fit(taxi_copy, taxi_copy.fare_amount)
rfe_support = rfe_selector.get_support()
rfe_support
# Out:
# Fitting estimator with 13 features.
# array([False,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True])

# %%
dict = {'Selected' : rfe_support, 'Features' : taxi_copy.columns}
selected_features = pd.DataFrame.from_dict(dict)
selected_features
# Out:
#     Selected           Features
# 0      False           VendorID
# 1       True      trip_distance
# 2       True   pickup_longitude
# 3       True    pickup_latitude
# 4       True         RatecodeID
# 5       True  dropoff_longitude
# 6       True   dropoff_latitude
# 7       True        fare_amount
# 8       True            weekday
# 9      False        pickup_hour
# 10      True       dropoff_hour
# 11      True    delta_longitude
# 12      True     delta_latitude

# %%
test = taxi_copy.drop(columns=['VendorID', 'pickup_hour'])
test
# Out:
#        trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0               1.04        -73.956322        40.781319           0
# 1               2.78        -73.987045        40.720921           0
# 2               2.40        -73.975731        40.758167           0
# 3               1.90        -73.961922        40.779140           0
# 4               0.47        -74.002571        40.739639           0
# ...              ...               ...              ...         ...
# 28447           0.82        -73.972549        40.756130           0
# 28448           9.07        -73.987480        40.765659           0
# 28450           5.90        -74.006958        40.729401           0
# 28452           1.50        -73.988831        40.743351           0
# 28453           0.65        -73.983673        40.766930           0
#
#        dropoff_longitude  dropoff_latitude  fare_amount  weekday  \
# 0             -73.960297         40.769520          6.0        6
# ...

# %% [markdown]
# Our final transformed dataset consist of 11 features and 26,312 observations

# %%
# Define the training data
X = test.drop(columns=['fare_amount'])
y = test['fare_amount'].values

print(X.shape)
print(y.shape)
# Out:
# (26312, 10)
# (26312,)

# %% [markdown]
# ### Grid search

# %%
# Grid search
model = RandomForestRegressor()
parameters = {'max_depth' : sp_randInt(1, 10),
              'max_features': sp_randInt(1, 9),
              'n_estimators' : sp_randInt(10, 1000),
              }
randm = RandomizedSearchCV(estimator=model, param_distributions=parameters, cv=2, n_iter=10, n_jobs=-1)
randm.fit(test, y)

print("\n *********************************************")
print("Results from random search")
print("************************************************")
print("\n The best estimator across ALL searched params:\n", randm.best_estimator_)
print("\n The best score across ALL searched params:\n", randm.best_score_)
print("\n The best parameters across ALL searched params:\n", randm.best_params_)
print("\n *********************************************")
# Out:
#  *********************************************
# Results from random search
# ************************************************
#
#  The best estimator across ALL searched params:
#  RandomForestRegressor(max_depth=9, max_features=8, n_estimators=576)
#
#  The best score across ALL searched params:
#  0.992080673523243
#
#  The best parameters across ALL searched params:
#  {'max_depth': 9, 'max_features': 8, 'n_estimators': 576}
#
#  *********************************************

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # Split into train and test sets

# %%
forest_model = RandomForestRegressor(n_estimators = 576, max_depth= 9, max_features=8, n_jobs = -1 )
forest_model.fit(X_train.values , y_train)
forest_model.feature_importances_
# Out:
# array([0.80642225, 0.00336781, 0.00204206, 0.11552735, 0.00754162,
#        0.00636061, 0.00333733, 0.0103629 , 0.02371072, 0.02132734])

# %%
y_train_pred_rand = forest_model.predict(X_train)
y_test_pred_rand= forest_model.predict(X_test)

# %%
plot_prediction_analysis(y_train, y_train_pred_rand, title='Random forest Model - Trainingset')

# %%
plot_prediction_analysis(y_test, y_test_pred_rand, title='Random forest Model - Testset')

# %% [markdown]
# As in the previous steps we calculate MAPE for this optimized model

# %%
mape_errors_rand = mape(y_test, y_test_pred_rand)
mape_errors_rand
# Out:
# /var/folders/7c/xgw1r9d13vn4sv16v1058m0c0000gn/T/ipykernel_8562/807224232.py:6: RuntimeWarning:
#
# divide by zero encountered in divide
# [array([ 7.07577006,  3.3283045 , 10.14504157, ..., 19.15297159,
#          4.81809145,  2.11546859])]

# %%
max(mape_errors_rand[0])
# Out:
# inf

# %% [markdown]
# Filter the outlier errors

# %%
outliers = []
[outliers.append(x) for x in mape_errors_rand[0] if x >= 50]
print('The number of predictions made with MAPE above 50% reasonable threshold is {} out of {} predictions made on the test set '.format(len(outliers), len(y_test)))
# Out:
# The number of predictions made with MAPE above 50% reasonable threshold is 20 out of 7894 predictions made on the test set

# %%
# Plot the MAPE errors
fig = plt.figure(figsize=(20,10))
plt.hist(filtered_data, bins=50)
plt.grid(True)
plt.xlabel('Mape Errors')
plt.ylabel('Occurences')
plt.title('MAPE on the test set using a Random forest model')
ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
plt.show()

# %% [markdown]
# The results of the Rmse and MAPE show that reducing the feature space by feature importance ranking and feature selection techniques eliminates noise and leads to a slightly better model. The new model has an average Rmse of 2.07 compared to 2.09 in the initial model. Checking the MAPE plots we can see that over 90% of the predictions fall below our previously set threshold 20 %.
#
# In the final steps we will serialize this model and save it in a folder for future analysis

# %%
test.columns
# Out:
# Index(['trip_distance', 'pickup_longitude', 'pickup_latitude', 'RatecodeID',
#        'dropoff_longitude', 'dropoff_latitude', 'fare_amount', 'weekday',
#        'dropoff_hour', 'delta_longitude', 'delta_latitude'],
#       dtype='object')

# %%
with open('./model/best_model.pkl', 'wb') as pkl:
    pickle.dump(forest_model, pkl)

# %% [markdown]
# # Results and Conclusions
#
# 1. It is possible to create a machine learning model to accurately predict the fare amount of taxi trips in real time with features containing the following information;
#     - trip distance
#     - pickup longitude
#     - pickup latitude
#     - Ratecode ID
#     - dropoff longitude
#     - dropoff latitude
#     - weekday
#     - dropoff_hour
#     - delta longitude
#     - delta latitude
# 2. The direction of the trip relative to the city center does not have a significant effect on the fare amount charges.
# 3. The cheapest times to commute by taxi in Newyork city is between 5:00 am to 12:00 pm
# 4. There is a direct linear relationship between the distance travelled and the fare amount. The farther you travel the more you pay with a rate of approximately 5 USD per mile.
# 5. Shorter trips are more susceptible to higher variations in the fare amount especially during rush-hour/peak periods where traffic plays a huge role.
# 6. Travelling to and fro the airports in Newyork (NYC) is often charged at a fixed price despite distance.

# %% [markdown]
# # References
#
# 1. [https://www.google.com/search?q=what+is+the+size+of+new+york+in+square+miles&sxsrf=ALiCzsYNtrBHTbzEVoJAw3TNNe9KPxU-kg%3A1670700526010&ei=7t2UY6YZjpTFzw_6goiwDw&oq=what+is+the+size+of+new+york+in+s&gs_lcp](https://www.google.com/search?q=what+is+the+size+of+new+york+in+square+miles&sxsrf=ALiCzsYNtrBHTbzEVoJAw3TNNe9KPxU-kg%3A1670700526010&ei=7t2UY6YZjpTFzw_6goiwDw&oq=what+is+the+size+of+new+york+in+s&gs_lcp=Cgxnd3Mtd2l6LXNlcnAQARgAMgUIABCABDIGCAAQFhAeMgYIABAWEB4yBggAEBYQHjIGCAAQFhAeMgYIABAWEB4yBggAEBYQHjIFCAAQhgMyBQgAEIYDMgUIABCGAzoKCAAQRxDWBBCwAzoHCAAQsAMQQzoFCCEQoAE6BAghEBU6CAghEBYQHhAdSgQIQRgASgQIRhgAULsIWMgbYLolaAJwAXgAgAG2AYgByQaSAQMwLjaYAQCgAQHIAQrAAQE&sclient=gws-wiz-serp.)
# 2. [https://builtin.com/data-science/when-and-why-standardize-your-data#:~:text=Standard%20Normal%20Distribution-,Standardization,-Standardization%20comes%20into](https://builtin.com/data-science/when-and-why-standardize-your-data#:~:text=Standard%20Normal%20Distribution-,Standardization,-Standardization%20comes%20into.)
# 3. [https://www.nyc.gov/site/tlc/passengers/taxi-fare.page#:~:text=%242.50%20initial%20charge,and%20any%20tolls](https://www.nyc.gov/site/tlc/passengers/taxi-fare.page#:~:text=%242.50%20initial%20charge,and%20any%20tolls.)
# 4. [https://www.investopedia.com/articles/personal-finance/021015/uber-versus-yellow-cabs-new-york-city.asp#:~:text=NYC%20cab%20drivers,through%20the%20app](https://www.investopedia.com/articles/personal-finance/021015/uber-versus-yellow-cabs-new-york-city.asp#:~:text=NYC%20cab%20drivers,through%20the%20app.)
# 5. [https://www.kaggle.com/code/prashant111/bagging-vs-boosting/notebook](https://www.kaggle.com/code/prashant111/bagging-vs-boosting/notebook.)
# 6. [https://medium.com/swlh/interpreting-linear-regression-through-statsmodels-summary-4796d359035a](https://medium.com/swlh/interpreting-linear-regression-through-statsmodels-summary-4796d359035a.)
# 7. [https://medium.com/swlh/interpreting-linear-regression-through-statsmodels-summary-4796d359035a](https://medium.com/swlh/interpreting-linear-regression-through-statsmodels-summary-4796d359035a.)
# 8. [https://machinelearningmastery.com/rfe-feature-selection-in-python/](https://machinelearningmastery.com/rfe-feature-selection-in-python/.)
# 9. [https://towardsdatascience.com/the-5-feature-selection-algorithms-every-data-scientist-need-to-know-3a6b566efd2](https://towardsdatascience.com/the-5-feature-selection-algorithms-every-data-scientist-need-to-know-3a6b566efd2.)
# 10. [https://www.travelmath.com/cities/](https://www.travelmath.com/cities/.)
